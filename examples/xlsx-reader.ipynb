# %%
import pandas as pd

df = pd.read_excel('sample/xlsx/fakegenerator/people-aroundtheworld.xlsx')  
print(df.info())
df.head()
print(df)
subset = df[["Age", "Occupation", "Vehicle"]]
subset.head()
print(subset)
age_above_35 = df[df["Age"] > 35]
age_above_35.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 45 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Number                100000 non-null  int64
#  1   Gender                100000 non-null  object
#  2   NameSet               100000 non-null  object
#  3   Title                 100000 non-null  object
#  4   GivenName             100000 non-null  object
#  5   MiddleInitial         97207 non-null   object
#  6   Surname               97317 non-null   object
#  7   StreetAddress         100000 non-null  object
#  8   City                  100000 non-null  object
#  9   State                 73806 non-null   object
#  10  StateFull             77047 non-null   object
#  11  ZipCode               100000 non-null  object
#  12  Country               100000 non-null  object
#  13  CountryFull           100000 non-null  object
# ...
